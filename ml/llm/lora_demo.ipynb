# %%
import torch
import torch.nn as nn

import gpt.classification
import gpt.configs
import gpt.mygpt
import gpt.spam

from gpt.text import Generator
from gpt.utils import (
    count_trainable_parameters,
    gpt_from_pretrained_url,
)

# %%
# Load the pretrained model.
gpt2 = gpt_from_pretrained_url(
    gpt.configs.GPT_CONFIG_124M,
    "gpt2-small (124M)",
)

# Verify it's correct, this should produce coherent text.
gen = Generator(gpt2)
gen.encode("Every effort moves you")
print(gen.generate(25))
print("Trainable parameters:", count_trainable_parameters(gpt2))
# Out:
# Every effort moves you forward.
#
# The first step is to understand the importance of your work.
#
# The second step is to understand the
# Trainable parameters: 163037184

# %%
spam_data = gpt.spam.prepare_spam_data(gen._tokenizer)
# Out:
# .cache/sms_spam_collection/SMSSpamCollection.tsv already exists. Skipping download and extraction

# %%
# Freeze the model.
for param in gpt2.parameters():
    param.requires_grad = False

# Replace the final output head with a classification layer.
torch.manual_seed(123)
num_classes = 2
gpt2.out_head = torch.nn.Linear(
    in_features=gpt.configs.GPT_CONFIG_124M["emb_dim"],
    out_features=num_classes,
)

# Make the final layer norm and last transformer block trainable.
# This leads to better results in practice.
for param in gpt2.trf_blocks[-1].parameters():
    param.requires_grad = True
for param in gpt2.final_norm.parameters():
    param.requires_grad = True

# %%
import time

start_time = time.time()
torch.manual_seed(123)
optimizer = torch.optim.AdamW(gpt2.parameters(), lr=5e-5, weight_decay=0.1)
num_epochs = 5

train_losses, val_losses, train_accs, val_accs, examples_seen = (
    gpt.classification.train_classifier_simple(
        gpt2,
        spam_data["train"],
        spam_data["validation"],
        optimizer,
        torch.device('cpu'),
        num_epochs=num_epochs,
        eval_freq=50,
        eval_iter=5,
    )
)

end_time = time.time()
execution_time_minutes = (end_time - start_time) / 60
print(f"Training completed in {execution_time_minutes:.2f} minutes.")
# Out:
# Ep 1 (Step 000000): Train loss 2.155, Val loss 2.861
# Ep 1 (Step 000050): Train loss 0.631, Val loss 0.618
# Ep 1 (Step 000100): Train loss 0.498, Val loss 0.561
# Training accuracy: 75.00% | Validation accuracy: 77.500000%
# Ep 2 (Step 000150): Train loss 0.494, Val loss 0.507
# Ep 2 (Step 000200): Train loss 0.363, Val loss 0.478
# Ep 2 (Step 000250): Train loss 0.455, Val loss 0.359
# Training accuracy: 70.00% | Validation accuracy: 92.500000%
# Ep 3 (Step 000300): Train loss 0.414, Val loss 0.442
# Ep 3 (Step 000350): Train loss 0.491, Val loss 0.350
# Training accuracy: 87.50% | Validation accuracy: 87.500000%
# Ep 4 (Step 000400): Train loss 0.234, Val loss 0.223
# Ep 4 (Step 000450): Train loss 0.212, Val loss 0.223
# Ep 4 (Step 000500): Train loss 0.153, Val loss 0.094
# Training accuracy: 97.50% | Validation accuracy: 97.500000%
# Ep 5 (Step 000550): Train loss 0.139, Val loss 0.099
# Ep 5 (Step 000600): Train loss 0.049, Val loss 0.097
# Training accuracy: 95.00% | Validation accuracy: 95.000000%
# Training completed in 4.96 minutes.

# %%
def count_trainable_parameters(model):
  return sum(
      p.numel() for p in model.parameters() if p.requires_grad
  )

# %%
count_trainable_parameters(gpt2)
# Out:
# 7090946

# %%
class LoRALayer(nn.Module):
    def __init__(self, in_dim, out_dim, rank, alpha):
        super().__init__()
        std = 1 / torch.sqrt(torch.tensor(rank).float())
        self.A = nn.Parameter(torch.randn(in_dim, rank) * std)
        self.B = nn.Parameter(torch.zeros(rank, out_dim))
        self.alpha = alpha

    def forward(self, x):
        x = self.alpha * (x @ self.A @ self.B)
        return x

class LinearWithLoRA(nn.Module):
    def __init__(self, linear, rank, alpha):
        super().__init__()
        self.lora = LoRALayer(
            linear.in_features, linear.out_features, rank, alpha
        )
        self.linear = linear

    def forward(self, x):
        return self.linear(x) + self.lora(x)

# %%
gpt_lora = gpt_from_pretrained_url(
    gpt.configs.GPT_CONFIG_124M,
    "gpt2-small (124M)",
)
print("Trainable parameters:", count_trainable_parameters(gpt_lora))
# Out:
# Trainable parameters: 163037184

# %%
def lora_linear_layers(model, rank, alpha):
    children = list(model.named_children())
    for name, child in children:
        if isinstance(child, nn.Linear):
            lora = LinearWithLoRA(child, rank, alpha)
            setattr(model, name, lora)
        else:
            # Recursively freeze linear layers in children modules
            lora_linear_layers(child, rank, alpha)

# Freeze the model.
for param in gpt_lora.parameters():
    param.requires_grad = False

# Replace the final output head with a classification layer.
torch.manual_seed(123)
num_classes = 2
gpt_lora.out_head = torch.nn.Linear(
    in_features=gpt.configs.GPT_CONFIG_124M["emb_dim"],
    out_features=num_classes,
)

lora_linear_layers(gpt_lora, 8, 0.1)

print(
    "Trainable parameters after LoRA:",
    count_trainable_parameters(gpt_lora)
)
# Out:
# Trainable parameters after LoRA: 1334802

# %%
def train(gpt_model, num_epochs=5):
    start_time = time.time()
    torch.manual_seed(123)
    optimizer = torch.optim.AdamW(gpt_lora.parameters(), lr=5e-5, weight_decay=0.1)
    
    train_losses, val_losses, train_accs, val_accs, examples_seen = (
        gpt.classification.train_classifier_simple(
            gpt_model,
            spam_data["train"],
            spam_data["validation"],
            optimizer,
            torch.device('cpu'),
            num_epochs=num_epochs,
            eval_freq=50,
            eval_iter=5,
        )
    )
    
    end_time = time.time()
    execution_time_minutes = (end_time - start_time) / 60
    print(f"Training completed in {execution_time_minutes:.2f} minutes.")

# %%
# !pip install line_profiler
# Out:
# Requirement already satisfied: line_profiler in /Users/edwardwild/miniconda3/envs/llm/lib/python3.13/site-packages (4.2.0)

# %%
# %lprun -f gpt.classification.train_classifier_simple train(gpt_lora)
# Out:
# UsageError: Line magic function `%lprun` not found.

# %%
# %%prun -s cumulative -T prun0
train(gpt_lora, num_epochs=1)
# Out:
# Ep 1 (Step 000000): Train loss 2.252, Val loss 2.991
# Ep 1 (Step 000050): Train loss 0.646, Val loss 0.580
# Ep 1 (Step 000100): Train loss 0.416, Val loss 0.517
# Training accuracy: 77.50% | Validation accuracy: 90.000000%
# Training completed in 1.96 minutes.
#
# *** Profile printout saved to text file 'prun0'.
#          1271349 function calls (1134340 primitive calls) in 117.669 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        35    0.525    0.015  118.187    3.377 {method 'control' of 'select.kqueue' objects}
#        34    0.026    0.001   91.586    2.694 base_events.py:1960(_run_once)
# 58650/170    0.067    0.000   64.581    0.380 module.py:1747(_wrapped_call_impl)
# 58650/170    1.222    0.000   64.580    0.380 module.py:1755(_call_impl)
#       170    0.046    0.000   64.572    0.380 mygpt.py:142(forward)
#  2210/170    0.151    0.000   64.274    0.378 container.py:238(forward)
#      2040    0.907    0.000   64.033    0.031 mygpt.py:112(forward)
#       160    0.003    0.000   60.876    0.380 classification.py:34(_calc_loss_batch)
#       130    0.001    0.000   51.762    0.398 _tensor.py:592(backward)
#       130    0.001    0.000   51.253    0.394 __init__.py:243(backward)
#       130    0.175    0.001   51.248    0.394 graph.py:815(_engine_run_backward)
#     12410    3.465    0.000   48.621    0.004 2319871007.py:21(forward)
#       130   42.455    0.327   42.455    0.327 {method 'run_backward' of 'torch._C._EngineBase' objects}
#      2040    0.003    0.000   37.917    0.019 mygpt.py:92(forward)
#     12410    0.013    0.000   35.475    0.003 linear.py:124(forward)
#     12410   35.337    0.003   35.337    0.003 {built-in method torch._C._nn.linear}
#         1    0.007    0.007   26.107   26.107 classification.py:62(train_classifier_simple)
#      2040    4.985    0.002   23.436    0.011 mygpt.py:27(forward)
#         3    0.000    0.000   12.671    4.224 classification.py:116(evaluate_model)
#         6    0.000    0.000   12.662    2.110 classification.py:43(_calc_loss_loader)
#     12410    9.586    0.001    9.595    0.001 2319871007.py:9(forward)
#       116    8.755    0.075    8.843    0.076 {built-in method time.sleep}
#      2040    0.003    0.000    4.465    0.002 activation.py:733(forward)
#      2040    4.460    0.002    4.460    0.002 {built-in method torch._C._nn.gelu}
#         2    0.000    0.000    3.726    1.863 classification.py:4(_calc_accuracy_loader)
#      2040    2.065    0.001    2.065    0.001 {built-in method torch.softmax}
#       130    0.003    0.000    1.057    0.008 optimizer.py:465(wrapper)
#       130    0.002    0.000    1.044    0.008 optimizer.py:60(_use_grad)
#       130    0.001    0.000    1.041    0.008 adam.py:212(step)
#       130    0.000    0.000    0.990    0.008 optimizer.py:130(maybe_fallback)
#       130    0.001    0.000    0.990    0.008 adam.py:865(adam)
#       130    0.288    0.002    0.982    0.008 adam.py:344(_single_tensor_adam)
#      4250    0.006    0.000    0.729    0.000 normalization.py:216(forward)
#      4250    0.016    0.000    0.721    0.000 functional.py:2889(layer_norm)
#      4250    0.701    0.000    0.701    0.000 {built-in method torch.layer_norm}
#        34    0.001    0.000    0.537    0.016 selectors.py:540(select)
#      2040    0.475    0.000    0.475    0.000 {method 'masked_fill_' of 'torch._C.TensorBase' objects}
#      2040    0.307    0.000    0.307    0.000 {method 'contiguous' of 'torch._C.TensorBase' objects}
#     19240    0.260    0.000    0.260    0.000 {method 'sqrt' of 'torch._C.TensorBase' objects}
#      2040    0.259    0.000    0.259    0.000 {method 'bool' of 'torch._C.TensorBase' objects}
#     38480    0.139    0.000    0.139    0.000 {method 'mul_' of 'torch._C.TensorBase' objects}
#       340    0.000    0.000    0.134    0.000 sparse.py:189(forward)
#       340    0.000    0.000    0.133    0.000 functional.py:2437(embedding)
#       340    0.132    0.000    0.132    0.000 {built-in method torch.embedding}
#       179    0.001    0.000    0.107    0.001 dataloader.py:728(__next__)
#       179    0.001    0.000    0.099    0.001 dataloader.py:787(_next_data)
#       178    0.001    0.000    0.097    0.001 fetch.py:47(fetch)
#      1424    0.004    0.000    0.086    0.000 spam.py:93(__getitem__)
#       130    0.081    0.001    0.084    0.001 optimizer.py:931(zero_grad)
#     19240    0.070    0.000    0.070    0.000 {method 'lerp_' of 'torch._C.TensorBase' objects}
#     19240    0.067    0.000    0.067    0.000 {method 'add_' of 'torch._C.TensorBase' objects}
#      6290    0.006    0.000    0.067    0.000 dropout.py:69(forward)
#     19240    0.065    0.000    0.065    0.000 {method 'addcdiv_' of 'torch._C.TensorBase' objects}
#    110840    0.064    0.000    0.064    0.000 module.py:1927(__getattr__)
#      6290    0.038    0.000    0.061    0.000 functional.py:1401(dropout)
#      1424    0.002    0.000    0.059    0.000 indexing.py:1176(__getitem__)
#      1424    0.003    0.000    0.055    0.000 indexing.py:1719(_getitem_axis)
#     19240    0.051    0.000    0.051    0.000 {method 'addcmul_' of 'torch._C.TensorBase' objects}
#       130    0.029    0.000    0.049    0.000 adam.py:137(_init_group)
#      1424    0.003    0.000    0.043    0.000 frame.py:3983(_ixs)
#     58650    0.030    0.000    0.030    0.000 {built-in method torch._C._get_tracing_state}
#     19240    0.014    0.000    0.029    0.000 optimizer.py:89(_get_value)
#      1424    0.007    0.000    0.028    0.000 managers.py:958(fast_xs)
#      8160    0.023    0.000    0.023    0.000 {method 'view' of 'torch._C.TensorBase' objects}
#     10200    0.021    0.000    0.021    0.000 {method 'transpose' of 'torch._C.TensorBase' objects}
#        35    0.000    0.000    0.019    0.001 events.py:87(_run)
# 97044/91032    0.010    0.000    0.017    0.000 {built-in method builtins.isinstance}
#      2996    0.017    0.000    0.017    0.000 {built-in method torch.tensor}
#    2997/9    0.003    0.000    0.016    0.002 module.py:2836(train)
#     38870    0.010    0.000    0.012    0.000 __init__.py:380(is_compiling)
#      6290    0.012    0.000    0.012    0.000 {built-in method torch.dropout}
#      1424    0.001    0.000    0.012    0.000 base.py:378(interleaved_dtype)
#      1424    0.005    0.000    0.011    0.000 cast.py:1432(find_common_type)
#       439    0.001    0.000    0.011    0.000 profiler.py:776(__exit__)
#       178    0.000    0.000    0.010    0.000 collate.py:337(default_collate)
#   534/178    0.002    0.000    0.010    0.000 collate.py:118(collate)
#      6290    0.005    0.000    0.010    0.000 _VF.py:27(__getattr__)
#      2997    0.004    0.000    0.010    0.000 module.py:1944(__setattr__)
#     97226    0.010    0.000    0.010    0.000 {method 'append' of 'list' objects}
#       439    0.000    0.000    0.009    0.000 _ops.py:981(__call__)
#      3299    0.002    0.000    0.009    0.000 {built-in method builtins.any}
#     38480    0.008    0.000    0.008    0.000 {built-in method torch.is_complex}
#     19298    0.008    0.000    0.008    0.000 {method 'item' of 'torch._C.TensorBase' objects}
#       439    0.001    0.000    0.008    0.000 profiler.py:770(__enter__)
#      3286    0.002    0.000    0.008    0.000 {built-in method builtins.all}
#         5    0.000    0.000    0.008    0.002 module.py:2858(eval)
#       160    0.000    0.000    0.007    0.000 functional.py:3404(cross_entropy)
#      1424    0.002    0.000    0.007    0.000 series.py:1095(__getitem__)
#       439    0.000    0.000    0.007    0.000 _ops.py:1035(_must_dispatch_in_python)
#       160    0.007    0.000    0.007    0.000 {built-in method torch._C._nn.cross_entropy_loss}
#       439    0.000    0.000    0.007    0.000 _ops.py:1147(__call__)
#       439    0.001    0.000    0.007    0.000 _pytree.py:1410(tree_any)
#       439    0.006    0.000    0.006    0.000 {built-in method torch._ops.profiler._record_function_enter_new}
#        35    0.000    0.000    0.006    0.000 {method 'run' of '_contextvars.Context' objects}
#         2    0.000    0.000    0.006    0.003 traceback.py:249(extract_stack)
#      1424    0.001    0.000    0.006    0.000 frame.py:678(_constructor_sliced_from_mgr)
#         2    0.002    0.001    0.006    0.003 traceback.py:427(extract)
# 35801/31388    0.004    0.000    0.006    0.000 {built-in method builtins.len}
#     12404    0.005    0.000    0.005    0.000 {built-in method builtins.getattr}
#  3073/878    0.002    0.000    0.005    0.000 _pytree.py:1071(tree_iter)
#      2210    0.002    0.000    0.004    0.000 container.py:230(__iter__)
#      1424    0.001    0.000    0.004    0.000 series.py:1220(_get_value)
#       356    0.001    0.000    0.004    0.000 collate.py:243(collate_tensor_fn)
#     20764    0.003    0.000    0.004    0.000 _tensor.py:1197(__hash__)
#      1424    0.001    0.000    0.004    0.000 common.py:97(is_bool_indexer)
#      1424    0.003    0.000    0.004    0.000 generic.py:6236(__finalize__)
#      5985    0.001    0.000    0.004    0.000 module.py:2731(children)
#     19370    0.003    0.000    0.004    0.000 adam.py:914(<genexpr>)
#     58822    0.003    0.000    0.003    0.000 _jit_internal.py:101(is_scripting)
#         2    0.000    0.000    0.003    0.002 traceback.py:449(_extract_from_extended_frame_gen)
#      1424    0.001    0.000    0.003    0.000 generic.py:339(_from_mgr)
#       130    0.000    0.000    0.003    0.000 traceback.py:367(line)
#       266    0.000    0.000    0.003    0.000 traceback.py:341(_set_lines)
#      1424    0.001    0.000    0.003    0.000 indexing.py:1667(_validate_integer)
#       356    0.003    0.000    0.003    0.000 {built-in method torch.stack}
#        68    0.000    0.000    0.003    0.000 linecache.py:21(getline)
#      4250    0.001    0.000    0.003    0.000 __init__.py:38(__get__)
#         1    0.000    0.000    0.003    0.003 adamw.py:22(__init__)
#       130    0.002    0.000    0.003    0.000 __init__.py:89(_make_grads)
#         7    0.000    0.000    0.003    0.000 asyncio.py:206(_handle_events)
#         1    0.000    0.000    0.003    0.003 adam.py:34(__init__)
#      5696    0.001    0.000    0.003    0.000 generic.py:42(_instancecheck)
#        68    0.000    0.000    0.003    0.000 linecache.py:31(getlines)
#         8    0.000    0.000    0.003    0.000 zmqstream.py:573(_handle_events)
#         8    0.000    0.000    0.003    0.000 linecache.py:83(updatecache)
#         1    0.000    0.000    0.003    0.003 optimizer.py:341(__init__)
#      4272    0.003    0.000    0.003    0.000 generic.py:6301(__setattr__)
#      1424    0.001    0.000    0.002    0.000 blocks.py:2716(new_block)
#      5985    0.002    0.000    0.002    0.000 module.py:2740(named_children)
#      1424    0.002    0.000    0.002    0.000 generic.py:278(__init__)
#      3073    0.001    0.000    0.002    0.000 _pytree.py:829(_get_node_type)
#      2848    0.001    0.000    0.002    0.000 indexing.py:2765(check_dict_or_set_indexers)
#         6    0.000    0.000    0.002    0.000 {built-in method builtins.print}
#       296    0.002    0.000    0.002    0.000 {built-in method torch.zeros_like}
#      1756    0.001    0.000    0.002    0.000 _pytree.py:836(_is_leaf)
#        12    0.001    0.000    0.002    0.000 interactiveshell.py:3025(write)
#      1424    0.002    0.000    0.002    0.000 cast.py:1391(np_find_common_type)
#      4250    0.002    0.000    0.002    0.000 {built-in method torch._C._get_cudnn_enabled}
#       345    0.000    0.000    0.002    0.000 module.py:2620(parameters)
#       439    0.002    0.000    0.002    0.000 {built-in method torch._ops.profiler.}
#         4    0.000    0.000    0.002    0.000 ioloop.py:750(_run_callback)
#      1424    0.002    0.000    0.002    0.000 base.py:3777(get_loc)
#      2997    0.001    0.000    0.002    0.000 parameter.py:10(__instancecheck__)
#       345    0.000    0.000    0.002    0.000 module.py:2645(named_parameters)
#       130    0.000    0.000    0.002    0.000 optimizer.py:160(_default_to_fused_or_foreach)
#      2997    0.001    0.000    0.002    0.000 parameter.py:216(__instancecheck__)
#       345    0.000    0.000    0.002    0.000 module.py:2600(_named_members)
#      5696    0.001    0.000    0.002    0.000 generic.py:37(_check)
#         3    0.000    0.000    0.002    0.001 iostream.py:616(_flush)
#       170    0.002    0.000    0.002    0.000 {built-in method torch.arange}
#      1424    0.000    0.000    0.002    0.000 base.py:74(__len__)
#       439    0.001    0.000    0.002    0.000 profiler.py:759(__init__)
#       179    0.000    0.000    0.002    0.000 dataloader.py:722(_next_index)
#      2848    0.001    0.000    0.001    0.000 blocks.py:1253(iget)
#       358    0.000    0.000    0.001    0.000 {built-in method builtins.next}
#     20764    0.001    0.000    0.001    0.000 {built-in method builtins.id}
#      3073    0.001    0.000    0.001    0.000 _pytree.py:818(_is_namedtuple_instance)
#       723    0.001    0.000    0.001    0.000 typing.py:426(inner)
#         3    0.000    0.000    0.001    0.000 session.py:754(send)
#       179    0.000    0.000    0.001    0.000 sampler.py:326(__iter__)
#        17    0.000    0.000    0.001    0.000 attrsettr.py:43(__getattr__)
#      1424    0.001    0.000    0.001    0.000 generic.py:586(_get_axis)
#      2406    0.001    0.000    0.001    0.000 {built-in method builtins.iter}
#         2    0.001    0.001    0.001    0.001 {method 'readlines' of '_io._IOBase' objects}
#      1424    0.000    0.000    0.001    0.000 series.py:831(_values)
#         2    0.000    0.000    0.001    0.001 tokenize.py:451(open)
#      6420    0.001    0.000    0.001    0.000 {built-in method torch._C._has_torch_function_unary}
#         9    0.000    0.000    0.001    0.000 dataloader.py:480(__iter__)
#         8    0.000    0.000    0.001    0.000 zmqstream.py:614(_handle_recv)
#         9    0.000    0.000    0.001    0.000 dataloader.py:419(_get_iterator)
#        12    0.000    0.000    0.001    0.000 iostream.py:118(_run_event_pipe_gc)
#      9687    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#         9    0.000    0.000    0.001    0.000 dataloader.py:766(__init__)
#      1424    0.001    0.000    0.001    0.000 {built-in method numpy.empty}
#        12    0.000    0.000    0.001    0.000 iostream.py:655(write)
#       383    0.000    0.000    0.001    0.000 <frozen abc>:117(__instancecheck__)
#      2848    0.001    0.000    0.001    0.000 base.py:332(array)
#      4750    0.001    0.000    0.001    0.000 {built-in method torch._C._has_torch_function_variadic}
#      1438    0.000    0.000    0.001    0.000 sampler.py:167(__iter__)
#      1424    0.001    0.000    0.001    0.000 blocks.py:2674(get_block_type)
#         2    0.000    0.000    0.001    0.000 traceback.py:33(format_list)
#      2649    0.001    0.000    0.001    0.000 {method 'values' of 'dict' objects}
#         2    0.000    0.000    0.001    0.000 traceback.py:730(format)
#      1424    0.000    0.000    0.001    0.000 generic.py:4379(_set_is_copy)
#         9    0.000    0.000    0.001    0.000 dataloader.py:634(__init__)
#      4272    0.001    0.000    0.001    0.000 cast.py:1462(<genexpr>)
#       383    0.001    0.000    0.001    0.000 {built-in method _abc._abc_instancecheck}
#  2116/334    0.001    0.000    0.001    0.000 module.py:2787(named_modules)
#         1    0.000    0.000    0.001    0.001 random.py:98(manual_seed_all)
#        68    0.000    0.000    0.001    0.000 traceback.py:514(format_frame_summary)
#       130    0.001    0.000    0.001    0.000 {built-in method torch.ones_like}
#        35    0.001    0.000    0.001    0.000 socket.py:623(send)
#      1424    0.001    0.000    0.001    0.000 managers.py:2004(internal_values)
#         1    0.000    0.000    0.001    0.001 __init__.py:79(_lazy_call)
#         7    0.000    0.000    0.001    0.000 iostream.py:259(schedule)
#        17    0.001    0.000    0.001    0.000 attrsettr.py:66(_get_attr_opt)
#      1424    0.001    0.000    0.001    0.000 range.py:1009(__getitem__)
#      2848    0.001    0.000    0.001    0.000 common.py:372(apply_if_callable)
#       130    0.001    0.000    0.001    0.000 optimizer.py:177(<genexpr>)
#         8    0.000    0.000    0.001    0.000 zmqstream.py:546(_run_callback)
#      1424    0.001    0.000    0.001    0.000 construction.py:481(ensure_wrapped_if_datetimelike)
#         1    0.000    0.000    0.001    0.001 optimizer.py:1003(add_param_group)
#        12    0.000    0.000    0.001    0.000 iostream.py:577(_schedule_flush)
#       286    0.000    0.000    0.001    0.000 grad_mode.py:184(__init__)
#         4    0.000    0.000    0.001    0.000 iostream.py:276(<lambda>)
#       130    0.000    0.000    0.001    0.000 optimizer.py:412(_cuda_graph_capture_health_check)
#         4    0.000    0.000    0.001    0.000 iostream.py:278(_really_send)
#         8    0.000    0.000    0.001    0.000 iostream.py:157(_handle_event)
#        36    0.001    0.000    0.001    0.000 {built-in method posix.stat}
#      3733    0.001    0.000    0.001    0.000 {method 'add' of 'set' objects}
#        24    0.000    0.000    0.001    0.000 tasks.py:703(sleep)
#         2    0.001    0.000    0.001    0.000 {built-in method _io.open}
#         1    0.000    0.000    0.001    0.001 {built-in method builtins.exec}
#         3    0.000    0.000    0.001    0.000 session.py:690(serialize)
#         9    0.000    0.000    0.001    0.000 zmqstream.py:653(_rebuild_io_state)
#         1    0.000    0.000    0.001    0.001 <string>:1(<module>)
#       439    0.000    0.000    0.001    0.000 _pytree.py:603(_dict_flatten)
#      1424    0.001    0.000    0.001    0.000 {built-in method fromkeys}
#      1457    0.000    0.000    0.000    0.000 range.py:999(__len__)
#         2    0.000    0.000    0.000    0.000 tokenize.py:358(detect_encoding)
#      1424    0.000    0.000    0.000    0.000 indexing.py:1165(_check_deprecated_callable_usage)
#        68    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#       439    0.000    0.000    0.000    0.000 _ops.py:1037(<lambda>)
#      1424    0.000    0.000    0.000    0.000 base.py:909(__len__)
#      5994    0.000    0.000    0.000    0.000 {function _ParameterMeta.__instancecheck__ at 0x116d9ccc0}
#      1424    0.000    0.000    0.000    0.000 cast.py:1471(<genexpr>)
#      1424    0.000    0.000    0.000    0.000 utils.py:62(is_list_like_indexer)
#      4272    0.000    0.000    0.000    0.000 cast.py:1478(<genexpr>)
#         3    0.000    0.000    0.000    0.000 tokenize.py:382(read_or_stop)
#       340    0.000    0.000    0.000    0.000 {method 'to' of 'torch._C.TensorBase' objects}
#         3    0.000    0.000    0.000    0.000 {method 'readline' of '_io.BufferedReader' objects}
#        44    0.000    0.000    0.000    0.000 linecache.py:47(checkcache)
#      1424    0.000    0.000    0.000    0.000 indexing.py:161(iloc)
#      2848    0.000    0.000    0.000    0.000 managers.py:291(arrays)
#      3691    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#      2848    0.000    0.000    0.000    0.000 blocks.py:266(mgr_locs)
#         9    0.000    0.000    0.000    0.000 zmqstream.py:676(_update_handler)
#        12    0.000    0.000    0.000    0.000 session.py:92(json_packer)
#       136    0.000    0.000    0.000    0.000 traceback.py:359(_dedented_lines)
#         8    0.000    0.000    0.000    0.000 socket.py:771(recv_multipart)
#      1424    0.000    0.000    0.000    0.000 flags.py:87(allows_duplicate_labels)
#      1424    0.000    0.000    0.000    0.000 flags.py:51(__init__)
#       187    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#       130    0.000    0.000    0.000    0.000 _foreach_utils.py:12(_get_fused_kernels_supported_devices)
#      4272    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         4    0.000    0.000    0.000    0.000 socket.py:700(send_multipart)
#        12    0.000    0.000    0.000    0.000 iostream.py:127(_event_pipe_gc)
#      1424    0.000    0.000    0.000    0.000 collate.py:206(<genexpr>)
#         3    0.000    0.000    0.000    0.000 iostream.py:271(send_multipart)
#      1440    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x10485c0e8}
#        16    0.000    0.000    0.000    0.000 base_events.py:781(call_later)
#       187    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#        68    0.000    0.000    0.000    0.000 textwrap.py:419(dedent)
#       527    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#      2848    0.000    0.000    0.000    0.000 generic.py:405(flags)
#        12    0.000    0.000    0.000    0.000 __init__.py:183(dumps)
#        33    0.000    0.000    0.000    0.000 spam.py:101(__len__)
#        35    0.000    0.000    0.000    0.000 selector_events.py:740(_process_events)
#       286    0.000    0.000    0.000    0.000 {built-in method torch._C._set_grad_enabled}
#         5    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#      1863    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 session.py:649(msg)
#        12    0.000    0.000    0.000    0.000 futures.py:310(_set_result_unless_cancelled)
#         5    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#       264    0.000    0.000    0.000    0.000 eval_frame.py:126(_maybe_set_eval_frame)
#         4    0.000    0.000    0.000    0.000 iostream.py:587(_schedule_in_thread)
#       117    0.000    0.000    0.000    0.000 {built-in method posix.getppid}
#        12    0.000    0.000    0.000    0.000 encoder.py:183(encode)
#        16    0.000    0.000    0.000    0.000 base_events.py:805(call_at)
#      1424    0.000    0.000    0.000    0.000 generic.py:572(_get_axis_number)
#        33    0.000    0.000    0.000    0.000 frame.py:1643(__len__)
#        43    0.000    0.000    0.000    0.000 threading.py:1134(is_alive)
#       878    0.000    0.000    0.000    0.000 _pytree.py:575(_tuple_flatten)
#       261    0.000    0.000    0.000    0.000 {built-in method torch._C._get_privateuse1_backend_name}
#        12    0.000    0.000    0.000    0.000 encoder.py:205(iterencode)
#      1424    0.000    0.000    0.000    0.000 cast.py:1473(<genexpr>)
#         3    0.000    0.000    0.000    0.000 session.py:645(msg_header)
#         4    0.000    0.000    0.000    0.000 ioloop.py:604(call_later)
#      1424    0.000    0.000    0.000    0.000 managers.py:246(items)
#        26    0.000    0.000    0.000    0.000 enum.py:1603(__and__)
#         5    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#       130    0.000    0.000    0.000    0.000 overrides.py:1962(is_tensor_like)
#       177    0.000    0.000    0.000    0.000 enum.py:1585(_get_value)
#      1424    0.000    0.000    0.000    0.000 managers.py:1837(__init__)
#        12    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#        18    0.000    0.000    0.000    0.000 {method 'random_' of 'torch._C.TensorBase' objects}
#        14    0.000    0.000    0.000    0.000 dataloader.py:511(__len__)
#        10    0.000    0.000    0.000    0.000 {built-in method torch.randperm}
#        33    0.000    0.000    0.000    0.000 enum.py:1592(__or__)
#       520    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#        18    0.000    0.000    0.000    0.000 {built-in method torch.empty}
#         9    0.000    0.000    0.000    0.000 dataloader.py:98(_get_distributed_settings)
#        68    0.000    0.000    0.000    0.000 linecache.py:161(lazycache)
#         4    0.000    0.000    0.000    0.000 asyncio.py:216(call_at)
#       132    0.000    0.000    0.000    0.000 eval_frame.py:262(_is_skip_guard_eval_unsafe_stance)
#      1424    0.000    0.000    0.000    0.000 flags.py:55(allows_duplicate_labels)
#       333    0.000    0.000    0.000    0.000 module.py:2670(<lambda>)
#        70    0.000    0.000    0.000    0.000 traceback.py:441(extended_frame_gen)
#        84    0.000    0.000    0.000    0.000 enum.py:695(__call__)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:684(<lambda>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        16    0.000    0.000    0.000    0.000 events.py:113(__init__)
#        12    0.000    0.000    0.000    0.000 events.py:157(cancel)
#        62    0.000    0.000    0.000    0.000 textwrap.py:470(indent)
#        60    0.000    0.000    0.000    0.000 __init__.py:183(sub)
#      1424    0.000    0.000    0.000    0.000 managers.py:1940(_block)
#         6    0.000    0.000    0.000    0.000 jsonutil.py:107(json_default)
#       130    0.000    0.000    0.000    0.000 {built-in method torch._C._are_functorch_transforms_active}
#         3    0.000    0.000    0.000    0.000 session.py:675(sign)
#        70    0.000    0.000    0.000    0.000 traceback.py:376(walk_stack)
#      1424    0.000    0.000    0.000    0.000 multiarray.py:690(result_type)
#      1424    0.000    0.000    0.000    0.000 generic.py:363(attrs)
#         3    0.000    0.000    0.000    0.000 session.py:272(msg_header)
#       429    0.000    0.000    0.000    0.000 {built-in method torch.is_grad_enabled}
#        14    0.000    0.000    0.000    0.000 sampler.py:340(__len__)
#        13    0.000    0.000    0.000    0.000 base_events.py:823(call_soon)
#         1    0.000    0.000    0.000    0.000 2588123344.py:1(train)
#      1424    0.000    0.000    0.000    0.000 base.py:6672(_maybe_cast_indexer)
#        10    0.000    0.000    0.000    0.000 {built-in method torch.argmax}
#        24    0.000    0.000    0.000    0.000 sampler.py:160(num_samples)
#        29    0.000    0.000    0.000    0.000 events.py:36(__init__)
#        10    0.000    0.000    0.000    0.000 {method 'tolist' of 'torch._C.TensorBase' objects}
#       130    0.000    0.000    0.000    0.000 __init__.py:233(_tensor_or_tensors_to_tuple)
#         5    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#        14    0.000    0.000    0.000    0.000 sampler.py:194(__len__)
#       128    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#        10    0.000    0.000    0.000    0.000 {method 'sum' of 'torch._C.TensorBase' objects}
#         9    0.000    0.000    0.000    0.000 distributed_c10d.py:1269(is_initialized)
#       528    0.000    0.000    0.000    0.000 {built-in method torch._C._dynamo.eval_frame.set_eval_frame}
#       132    0.000    0.000    0.000    0.000 eval_frame.py:179(_callback_from_stance)
#         6    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#         3    0.000    0.000    0.000    0.000 session.py:198(utcnow)
#       439    0.000    0.000    0.000    0.000 {method '__exit__' of 'torch._C.DisableTorchFunctionSubclass' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#        74    0.000    0.000    0.000    0.000 base_events.py:772(time)
#        13    0.000    0.000    0.000    0.000 base_events.py:852(_call_soon)
#       130    0.000    0.000    0.000    0.000 __init__.py:1750(getEffectiveLevel)
#       130    0.000    0.000    0.000    0.000 {method 'numel' of 'torch._C.TensorBase' objects}
#       130    0.000    0.000    0.000    0.000 _foreach_utils.py:8(_get_foreach_kernels_supported_devices)
#         6    0.000    0.000    0.000    0.000 iostream.py:710(_flush_buffers)
#         9    0.000    0.000    0.000    0.000 typing.py:1374(__instancecheck__)
#        60    0.000    0.000    0.000    0.000 __init__.py:330(_compile)
#        17    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#        68    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         9    0.000    0.000    0.000    0.000 zmqstream.py:532(sending)
#         1    0.000    0.000    0.000    0.000 random.py:88(_seed_custom_device)
#        13    0.000    0.000    0.000    0.000 grad_mode.py:84(__exit__)
#         9    0.000    0.000    0.000    0.000 typing.py:1665(__subclasscheck__)
#        12    0.000    0.000    0.000    0.000 base_events.py:457(create_future)
#       148    0.000    0.000    0.000    0.000 optimizer.py:209(_get_scalar_dtype)
#       178    0.000    0.000    0.000    0.000 <frozen _collections_abc>:345(__subclasshook__)
#         3    0.000    0.000    0.000    0.000 session.py:600(msg_id)
#         1    0.000    0.000    0.000    0.000 __init__.py:60(manual_seed)
#        84    0.000    0.000    0.000    0.000 enum.py:1152(__new__)
#         3    0.000    0.000    0.000    0.000 {built-in method now}
#         9    0.000    0.000    0.000    0.000 dataloader.py:75(create_fetcher)
#        12    0.000    0.000    0.000    0.000 iostream.py:505(parent_header)
#         3    0.000    0.000    0.000    0.000 hmac.py:122(copy)
#         7    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#        68    0.000    0.000    0.000    0.000 {method 'findall' of 're.Pattern' objects}
#       210    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 tokenize.py:388(find_cookie)
#       554    0.000    0.000    0.000    0.000 typing.py:2371(cast)
#       356    0.000    0.000    0.000    0.000 worker.py:101(get_worker_info)
#        11    0.000    0.000    0.000    0.000 {method 'manual_seed' of 'torch._C.Generator' objects}
#         9    0.000    0.000    0.000    0.000 queue.py:115(empty)
#       439    0.000    0.000    0.000    0.000 __init__.py:129(annotate)
#       160    0.000    0.000    0.000    0.000 _reduction.py:8(get_enum)
#        16    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#       130    0.000    0.000    0.000    0.000 __init__.py:39(is_built)
#       198    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#        13    0.000    0.000    0.000    0.000 <frozen codecs>:322(decode)
#        12    0.000    0.000    0.000    0.000 {built-in method math.isnan}
#        68    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 traceback.py:495(from_list)
#        13    0.000    0.000    0.000    0.000 grad_mode.py:75(__init__)
#        43    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         9    0.000    0.000    0.000    0.000 distributed_c10d.py:721(WORLD)
#         3    0.000    0.000    0.000    0.000 traitlets.py:2635(validate)
#         3    0.000    0.000    0.000    0.000 iostream.py:718(_rotate_buffers)
#       130    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#       260    0.000    0.000    0.000    0.000 decorators.py:261(graph_break)
#         3    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HMAC' objects}
#        13    0.000    0.000    0.000    0.000 grad_mode.py:80(__enter__)
#       264    0.000    0.000    0.000    0.000 {built-in method torch._C._dynamo.eval_frame.set_skip_guard_eval_unsafe}
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        13    0.000    0.000    0.000    0.000 _contextlib.py:154(__new__)
#         2    0.000    0.000    0.000    0.000 _utils.py:996(queue_seed_all)
#         1    0.000    0.000    0.000    0.000 __init__.py:2672(__getattr__)
#        62    0.000    0.000    0.000    0.000 textwrap.py:483(<lambda>)
#         3    0.000    0.000    0.000    0.000 iostream.py:725(_hooks)
#        13    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#       264    0.000    0.000    0.000    0.000 _utils_internal.py:172(justknobs_check)
#        17    0.000    0.000    0.000    0.000 zmqstream.py:528(receiving)
#         8    0.000    0.000    0.000    0.000 ioloop.py:549(time)
#         1    0.000    0.000    0.000    0.000 asyncio.py:231(add_callback)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#        15    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._mps_is_in_bad_fork}
#        12    0.000    0.000    0.000    0.000 events.py:73(cancel)
#        17    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#        43    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._log_api_usage_once}
#        12    0.000    0.000    0.000    0.000 hmac.py:117(update)
#         3    0.000    0.000    0.000    0.000 session.py:281(extract_header)
#         1    0.000    0.000    0.000    0.000 tokenize.py:347(_get_normal_name)
#         3    0.000    0.000    0.000    0.000 hmac.py:161(hexdigest)
#        74    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         4    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#        25    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        12    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HMAC' objects}
#         2    0.000    0.000    0.000    0.000 <frozen codecs>:312(__init__)
#         3    0.000    0.000    0.000    0.000 traitlets.py:2558(_validate_bounds)
#        68    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 jsonutil.py:38(_ensure_tzinfo)
#        84    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#       130    0.000    0.000    0.000    0.000 optimizer.py:451(_optimizer_step_code)
#         3    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HMAC' objects}
#        12    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#        16    0.000    0.000    0.000    0.000 typing.py:1443(__hash__)
#        43    0.000    0.000    0.000    0.000 {method 'is_done' of '_thread._ThreadHandle' objects}
#        23    0.000    0.000    0.000    0.000 dataloader.py:499(_index_sampler)
#        68    0.000    0.000    0.000    0.000 traceback.py:293(__init__)
#        62    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#       148    0.000    0.000    0.000    0.000 {built-in method torch.get_default_dtype}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#        43    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 optimizer.py:516(_patch_step_function)
#         9    0.000    0.000    0.000    0.000 __init__.py:14(is_available)
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         9    0.000    0.000    0.000    0.000 fetch.py:9(__init__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#        62    0.000    0.000    0.000    0.000 {method 'isspace' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 {built-in method time.time}
#        12    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#         9    0.000    0.000    0.000    0.000 queue.py:267(_qsize)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         7    0.000    0.000    0.000    0.000 base_events.py:1945(_add_callback)
#        13    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#        15    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#        32    0.000    0.000    0.000    0.000 dataloader.py:495(_auto_collation)
#         8    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#        17    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 history.py:1016(_writeout_output_cache)
#        43    0.000    0.000    0.000    0.000 threading.py:605(is_set)
#        24    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        53    0.000    0.000    0.000    0.000 base_events.py:2058(get_debug)
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#         7    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#        29    0.000    0.000    0.000    0.000 base_events.py:554(_check_closed)
#         4    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#        12    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        15    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#        14    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        12    0.000    0.000    0.000    0.000 encoder.py:105(__init__)
#        12    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         1    0.000    0.000    0.000    0.000 __init__.py:29(<lambda>)
#        11    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        16    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 threading.py:318(_is_owned)
#         1    0.000    0.000    0.000    0.000 threading.py:303(__enter__)
#        12    0.000    0.000    0.000    0.000 displaypub.py:150(is_publishing)
#         4    0.000    0.000    0.000    0.000 events.py:129(__lt__)
#        12    0.000    0.000    0.000    0.000 base_events.py:1955(_timer_handle_cancelled)
#         2    0.000    0.000    0.000    0.000 {method 'seek' of '_io.BufferedReader' objects}
#         3    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#         3    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:312(_release_save)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         3    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#        12    0.000    0.000    0.000    0.000 displayhook.py:118(is_active)
#         2    0.000    0.000    0.000    0.000 {method 'startswith' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup}
#         4    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         9    0.000    0.000    0.000    0.000 distributed_c10d.py:596(default_pg)
#         1    0.000    0.000    0.000    0.000 __init__.py:294(is_initialized)
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'group' of 're.Match' objects}
#         1    0.000    0.000    0.000    0.000 history.py:1065(hold)
#         2    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'isdisjoint' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 <frozen codecs>:263(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:51(<lambda>)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 hmac.py:139(_current)
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 __init__.py:74(is_initialized)
#         1    0.000    0.000    0.000    0.000 __init__.py:19(_get_default_mps_generator)
#       1/0    0.000    0.000    0.000          traceback.py:242(format_stack)
#     131/0    0.000    0.000    0.000          _compile.py:41(inner)
#     131/0    0.001    0.000    0.000          eval_frame.py:829(_fn)

# %%
# !ls
